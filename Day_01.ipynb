# %% [markdown]
# ### **This is a band name generator created by the one and only Afshan Afridi on Day 01 of 100 days of python**

# %%
print("Welcome to a band name generator")

name = input(print("What is the name of the city in which you grew up in?"))

pet_name= input(print("what is the name of your pet?"))

print("Then your band name could be ",name, pet_name)
# Out:
# Welcome to a band name generator
# What is the name of the city in which you grew up in?
# what is the name of your pet?
# Then your band name could be  Karachi Catty
